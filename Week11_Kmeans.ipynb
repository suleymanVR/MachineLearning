# %% [markdown]
# <a href="https://colab.research.google.com/github/suleymanVR/MachineLearning/blob/main/Week11_Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets

# %%
iris = pd.read_csv('Iris.csv')

# %%
iris['Species'] = iris.Species.str.replace('Iris-' , '')

# %%
data = iris.iloc[:, [1,2,3,4]]

# %%
data  = np.array(data)

# %%
# Collecting the distortions into list
distortions = []
for k in range(1,10):
 kmeanModel = KMeans(n_clusters=k)
 kmeanModel.fit(data)
 distortions.append(kmeanModel.inertia_)
# Plotting the distortions
plt.figure(figsize=(8,4))
plt.plot(K, distortions, 'bx-')
plt.xlabel('number of k (cluster) value')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal clusters')
plt.show()

# %%
for i in range(1,4):
  kmeans_model = KMeans(n_clusters=i, random_state=32932)
  kmeans_predict = kmeans_model.fit_predict(data)

  iris['Cluster'] = kmeans_predict

  plt.scatter(data[kmeans_predict == 0, 0], data[kmeans_predict == 0, 1], s = 100, c = 'red', label = 'Setosa')
  plt.scatter(data[kmeans_predict == 1, 0], data[kmeans_predict == 1, 1], s = 100, c = 'blue', label = 'Versicolour')
  plt.scatter(data[kmeans_predict == 2, 0], data[kmeans_predict == 2, 1], s = 100, c = 'green', label = 'Virginica')
  # Plotting the centroids of the clusters
  plt.scatter(kmeans_model.cluster_centers_[:, 0], kmeans_model.cluster_centers_[:,1], s = 100, c = 'yellow', label = 'Centroids')
  plt.legend()
  plt.show()
